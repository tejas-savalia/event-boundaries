# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast, os
import bambi as bmb
import pymc as pm
import arviz as az
import scipy.stats as stat
from collections import Counter

# %% [markdown]
# # Function to clean the data files
#
# #### For each data file this function does the following:
# 1. Drops irrelevant columns
# 2. Computes accuracies (accurate if all correct keys pressed on the first try)
# 3. Label Node types: Boundary vs non boundary
# 4. Label transition types: Cross cluster or within cluster
# 4. Label other relevant conditions like walk length, number of keypresses, etc.

# %%
def clean_data(filename):
    # print(filename)

    try:
        data = pd.read_csv('data/' + filename)

        # Drop instruction rows by dropping rows with missing data in column: 'blocks.thisRepN'
        data = data.dropna(subset=['blocks.thisRepN']).reset_index(drop=True)

        if len(data) < 1400:
            raise TypeError('Incomplete Data')

        #Compute accuracy as True if number of response values are the same as number of stim values
        # print(data['stim'])
        data['accuracy'] = [True if (len(ast.literal_eval(data['stim'][i])) == len(ast.literal_eval(data['key_resp.rt'][i]))) else False for i in range(len(data))]


        data['node_type'] = ['Boundary' if data['node idx'][i] in [0, 4, 5, 9, 10, 14] else 'Non Boundary' for i in range(len(data))]

        data['rt'] = [np.mean(ast.literal_eval(data['key_resp.rt'][i])) if data['accuracy'][i] else np.NaN for i in range(len(data))]
        data['transition_type'] = ['cross cluster' if (data['node_type'] == 'Boundary')[i] & (data['node_type'].shift() == 'Boundary')[i] else 'within cluster' for i in range(len(data))]

        if data['participant'][0]%4 == 0:
            data['walk_length'] = 0
        elif data['participant'][0]%4 == 1:
            data['walk_length'] = 3
        elif data['participant'][0]%4 == 2:
            data['walk_length'] = 6
        else:
            data['walk_length'] = 1400

        data['trial'] = np.arange(len(data))
        
        #Count the lag to indicate when the same stimulus was seen previously. Lag = 1 means the previous trial had the same stimulus.
        lag_counter_dict = Counter()
        lag = []

        for s in data['stim']:
            lag.append(lag_counter_dict[s])
            lag_counter_dict.update(lag_counter_dict.keys())
            lag_counter_dict[s] = 1
            # print(lag_counter_dict)
        data['lag'] = lag
        
    except:
        return None
    data['num_keypress'] = [len(ast.literal_eval(data['stim'][i])) for i in range(len(data))]

    return data[['participant', 'trial', 'blocks.thisRepN', 'accuracy', 'walk_length', 'node_type', 'transition_type', 'rt', 'stim', 'num_keypress', 'lag']]

# %% [markdown]
# # Read the data files

# %%
data_files = []
for f in os.listdir('data/'):
    if (f.startswith('30') & f.endswith('csv')):
        data_files.append(f)

# %% [markdown]
# # Clean the data files into a single large dataframe
#
# 1. Label Trials, conditions, etc.
# 2. Combine relevant columns of extracted data files
# 3. Specify outliers and remove them

# %%
df_clean = pd.concat([clean_data(f) for f in data_files]).reset_index(drop = True)
df_clean['reset'] = 'False'
df_clean.loc[df_clean['trial'].values%(df_clean['walk_length'].values+1) == 0, 'reset'] = 'True'



df_clean_rt_outlier = df_clean[np.abs(stat.zscore(df_clean['rt'], nan_policy='omit')) < 3]
df_clean_rt_outlier['node_transition_type'] = df_clean_rt_outlier['node_type'] + ' ' + df_clean_rt_outlier['transition_type']

# df_clean_participant = df_clean_rt_outlier.groupby(['participant', 'blocks.thisRepN', 'walk_length', 'node_type', 'transition_type', 'num_keypress']).median().reset_index()

df_clean = df_clean.loc[stat.zscore(df_clean['rt']) < 3].reset_index()

# %%
df_clean_rt_outlier['walk_length'] = df_clean_rt_outlier.walk_length.astype('str')

# %% [markdown]
# # Plot Accuracies

# %%
sns.set_context('paper')
sns.set_theme()
sns.catplot(y = 'accuracy', 
            x = 'blocks.thisRepN', col = 'walk_length', hue = 'node_type', col_wrap=2,
            kind = 'point',
            data=df_clean)

# %%
sns.lmplot(y = 'rt', 
            x = 'trial', col = 'walk_length', hue = 'transition_type',
            data=df_clean_rt_outlier, scatter_kws={'alpha': 0.1})

# %%
sns.catplot(y = 'rt', 
            x = 'blocks.thisRepN', col = 'walk_length', hue = 'transition_type',
            kind = 'point', estimator='median', margin_titles=True,
            data=df_clean_rt_outlier)

# %%
sns.catplot(y = 'rt', 
             x = 'walk_length', 
            row_order=['Non Boundary', 'Boundary'], margin_titles=True,
            kind = 'point', estimator='median',
            data=df_clean_rt_outlier)

# %%
sns.catplot(y = 'rt', x = 'walk_length', estimator = 'median', kind = 'point', data = df_clean_rt_outlier_median)

# %%
block_cutoff = 0
g = sns.displot(x = 'rt', hue='transition_type', col='walk_length', 
             col_wrap=2, 
             data = df_clean_rt_outlier.loc[df_clean_rt_outlier['blocks.thisRepN'] > block_cutoff])
walk_lengths = [0, 3, 6, 1400]
for i in range(4):
    g.axes[i].axvline(np.nanmedian(df_clean_rt_outlier.loc[((df_clean_rt_outlier['blocks.thisRepN'] > block_cutoff) & (df_clean_rt_outlier['transition_type'] == 'cross cluster') & (df_clean_rt_outlier['walk_length'] == str(walk_lengths[i]))), 'rt']), 
                      c = 'orange', ls = '--', alpha = 1)
    
    g.axes[i].axvline(np.nanmedian(df_clean_rt_outlier.loc[((df_clean_rt_outlier['blocks.thisRepN'] > block_cutoff) & (df_clean_rt_outlier['transition_type'] == 'within cluster') & (df_clean_rt_outlier['walk_length'] == str(walk_lengths[i]))), 'rt']), 
                      c = 'blue', ls = '--', alpha = 0.5)

    # g.axes[0][i].axvline(np.nanmedian(df_clean_rt_outlier.loc[((df_clean_rt_outlier['blocks.thisRepN'] > block_cutoff) & (df_clean_rt_outlier['node_type'] == 'Boundary') & (df_clean_rt_outlier['walk_length'] == walk_lengths[i])), 'rt']), c = 'orange', ls = '--')
    # g.axes[0][i].axvline(np.nanmedian(df_clean_rt_outlier.loc[((df_clean_rt_outlier['blocks.thisRepN'] > block_cutoff) & (df_clean_rt_outlier['node_type'] == 'Non Boundary') & (df_clean_rt_outlier['walk_length'] == walk_lengths[i])), 'rt']), c = 'blue', ls = '--')

# %%
sns.catplot(y = 'rt', 
            hue = 'reset', x = 'node_transition_type', col = 'walk_length', 
            # row_order=['Non Boundary', 'Boundary'], margin_titles=True,
            kind = 'box', estimator='median', col_wrap=2,
            data=df_clean_rt_outlier)

# %%
df_clean_rt_outlier['num_keypress'] = df_clean_rt_outlier['num_keypress'].astype(str)
df_clean_rt_outlier['walk_length'] = df_clean_rt_outlier['walk_length'].astype(str)

# %%
df_clean_rt_outlier
# Out:
#         participant  trial  blocks.thisRepN  accuracy walk_length  \
# 0            3000.0      0              0.0      True           0
# 2            3000.0      2              0.0      True           0
# 3            3000.0      3              0.0      True           0
# 4            3000.0      4              0.0      True           0
# 5            3000.0      5              0.0      True           0
# ...             ...    ...              ...       ...         ...
# 124593       3099.0   1393              6.0      True        1400
# 124594       3099.0   1394              6.0      True        1400
# 124595       3099.0   1395              6.0      True        1400
# 124598       3099.0   1398              6.0      True        1400
# 124599       3099.0   1399              6.0      True        1400
#
#            node_type transition_type        rt            stim  num_keypress  \
# 0           Boundary  within cluster  1.367459  ('l', 'space')             2
# 2           Boundary  within cluster  1.377622  ('j', 'space')             2
# 3       Non Boundary  within cluster  1.171814      ('j', 'k')             2
# 4           Boundary  within cluster  1.230127  ('l', 'space')             2
# 5           Boundary   cross cluster  0.726496  ('l', 'space')             2
# ...              ...             ...       ...             ...           ...
# 124593  Non Boundary  within cluster  1.021854  ('j', 'space')             2
# 124594      Boundary  within cluster  0.658679          ('k',)             1
# 124595  Non Boundary  within cluster  1.424606      ('h', 'k')             2
# 124598      Boundary  within cluster  0.701917          ('k',)             1
# 124599  Non Boundary  within cluster  1.286206      ('h', 'k')             2
#
#         lag  reset         node_transition_type
# 0         0   True      Boundary within cluster
# 2         0   True      Boundary within cluster
# 3         0   True  Non Boundary within cluster
# 4         4   True      Boundary within cluster
# 5         1   True       Boundary cross cluster
# ...     ...    ...                          ...
# 124593    4  False  Non Boundary within cluster
# 124594    9  False      Boundary within cluster
# 124595   48  False  Non Boundary within cluster
# 124598   12  False      Boundary within cluster
# 124599    2  False  Non Boundary within cluster
#
# [112819 rows x 13 columns]

# %%
df_clean_rt_outlier_median = df_clean_rt_outlier.loc[df_clean_rt_outlier['trial'] > 0].reset_index(drop=True).groupby(['participant', 'blocks.thisRepN', 'walk_length', 'node_type', 'transition_type', 'num_keypress', 'reset', 'node_transition_type']).median(numeric_only=True).reset_index()
df_clean_rt_outlier_median
# Out:
#       participant  blocks.thisRepN walk_length     node_type transition_type  \
# 0          3000.0              0.0           0      Boundary   cross cluster
# 1          3000.0              0.0           0      Boundary   cross cluster
# 2          3000.0              0.0           0      Boundary  within cluster
# 3          3000.0              0.0           0      Boundary  within cluster
# 4          3000.0              0.0           0  Non Boundary  within cluster
# ...           ...              ...         ...           ...             ...
# 5384       3099.0              6.0        1400      Boundary   cross cluster
# 5385       3099.0              6.0        1400      Boundary  within cluster
# 5386       3099.0              6.0        1400      Boundary  within cluster
# 5387       3099.0              6.0        1400  Non Boundary  within cluster
# 5388       3099.0              6.0        1400  Non Boundary  within cluster
#
#       num_keypress  reset         node_transition_type   trial  accuracy  \
# 0                1   True       Boundary cross cluster    72.0       1.0
# 1                2   True       Boundary cross cluster    90.0       1.0
# 2                1   True      Boundary within cluster    97.5       1.0
# 3                2   True      Boundary within cluster    71.0       1.0
# 4                1   True  Non Boundary within cluster   100.5       1.0
# ...            ...    ...                          ...     ...       ...
# 5384             2  False       Boundary cross cluster  1353.0       1.0
# 5385             1  False      Boundary within cluster  1317.5       1.0
# 5386             2  False      Boundary within cluster  1265.0       1.0
# 5387             1  False  Non Boundary within cluster  1314.0       1.0
# 5388             2  False  Non Boundary within cluster  1260.5       1.0
#
#             rt   lag
# 0     0.837338   9.0
# 1     1.442875   7.5
# 2     0.814899   9.5
# 3     1.370012  11.0
# 4     0.748597  11.0
# ...        ...   ...
# 5384  1.046889  25.0
# 5385  0.680682   6.0
# 5386  1.098368   3.0
# 5387  0.550517   3.0
# 5388  0.908185   5.0
#
# [5389 rows x 12 columns]

# %%
model = bmb.Model("rt ~ reset + lag + blocks.thisRepN*walk_length + walk_length*transition_type +  (transition_type|participant) + (blocks.thisRepN|participant) + (num_keypress|participant)", data = df_clean_rt_outlier_median)
model.build()
model.graph()

# %%
sample = model.fit()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [rt_sigma, Intercept, reset, lag, blocks.thisRepN, walk_length, blocks.thisRepN:walk_length, transition_type, walk_length:transition_type, 1|participant_sigma, 1|participant_offset, transition_type|participant_sigma, transition_type|participant_offset, blocks.thisRepN|participant_sigma, blocks.thisRepN|participant_offset, num_keypress|participant_sigma, num_keypress|participant_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 01:51&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 112 seconds.

# %%
coords = {'walk_length_dim': ['1400', '6', '3'], 
          'walk_length:transition_type_dim':['1400, within cluster', '6, within cluster', '3, within cluster'],
          'blocks.thisRepN:walk_length_dim':['1400', '6', '3'],
         }

# %%
az.plot_posterior(sample, point_estimate='median', ref_val=0, hdi_prob=.95, var_names='~participant', filter_vars='like', coords = coords)
plt.tight_layout()
plt.savefig('results/posteriors_bayesianmodel0_params.png', dpi = 600)

# %%
g = az.plot_forest(sample, var_names='~participant', filter_vars='like', kind = 'ridgeplot', ridgeplot_quantiles = [0.5], ridgeplot_alpha=0.2, ridgeplot_overlap=1, 
              coords = coords)
g[0].axvline(0, ls = '--', color = 'black')
plt.savefig('ridgeplot_bayesianmodel0_params.png', dpi = 600)

# %%
az.summary(sample, hdi_prob=.95, var_names = ['~participant'], filter_vars = 'like', coords=coords)
# Out:
#                                                     mean     sd  hdi_2.5%  \
# Intercept                                          0.469  0.036     0.397
# reset[True]                                        0.063  0.007     0.049
# lag                                                0.002  0.000     0.001
# blocks.thisRepN                                   -0.046  0.006    -0.057
# walk_length[1400]                                  0.147  0.049     0.051
# walk_length[6]                                     0.116  0.048     0.014
# walk_length[3]                                     0.025  0.046    -0.061
# blocks.thisRepN:walk_length[1400]                 -0.010  0.008    -0.026
# blocks.thisRepN:walk_length[6]                    -0.010  0.008    -0.025
# blocks.thisRepN:walk_length[3]                     0.001  0.008    -0.014
# transition_type[within cluster]                    0.003  0.020    -0.035
# walk_length:transition_type[1400, within cluster] -0.049  0.028    -0.104
# walk_length:transition_type[6, within cluster]    -0.046  0.027    -0.097
# walk_length:transition_type[3, within cluster]    -0.028  0.026    -0.084
# rt_sigma                                           0.204  0.002     0.200
#
#                                                    hdi_97.5%  mcse_mean  \
# Intercept                                              0.538      0.001
# reset[True]                                            0.077      0.000
# lag                                                    0.003      0.000
# blocks.thisRepN                                       -0.034      0.000
# walk_length[1400]                                      0.242      0.001
# walk_length[6]                                         0.203      0.001
# walk_length[3]                                         0.118      0.001
# blocks.thisRepN:walk_length[1400]                      0.006      0.000
# blocks.thisRepN:walk_length[6]                         0.007      0.000
# blocks.thisRepN:walk_length[3]                         0.017      0.000
# transition_type[within cluster]                        0.044      0.000
# walk_length:transition_type[1400, within cluster]      0.008      0.001
# walk_length:transition_type[6, within cluster]         0.009      0.001
# walk_length:transition_type[3, within cluster]         0.020      0.001
# rt_sigma                                               0.208      0.000
#
#                                                    mcse_sd  ess_bulk  \
# Intercept                                            0.000    3366.0
# reset[True]                                          0.000    6875.0
# lag                                                  0.000    8019.0
# blocks.thisRepN                                      0.000    1583.0
# walk_length[1400]                                    0.001    2923.0
# walk_length[6]                                       0.001    2973.0
# walk_length[3]                                       0.001    2990.0
# blocks.thisRepN:walk_length[1400]                    0.000    1433.0
# blocks.thisRepN:walk_length[6]                       0.000    1712.0
# blocks.thisRepN:walk_length[3]                       0.000    1498.0
# transition_type[within cluster]                      0.000    2411.0
# walk_length:transition_type[1400, within cluster]    0.000    2765.0
# walk_length:transition_type[6, within cluster]       0.000    2632.0
# walk_length:transition_type[3, within cluster]       0.000    2461.0
# rt_sigma                                             0.000    7226.0
#
#                                                    ess_tail  r_hat
# Intercept                                            3113.0    1.0
# reset[True]                                          2531.0    1.0
# lag                                                  2858.0    1.0
# blocks.thisRepN                                      2384.0    1.0
# walk_length[1400]                                    2992.0    1.0
# walk_length[6]                                       2796.0    1.0
# walk_length[3]                                       2738.0    1.0
# blocks.thisRepN:walk_length[1400]                    2576.0    1.0
# blocks.thisRepN:walk_length[6]                       2438.0    1.0
# blocks.thisRepN:walk_length[3]                       2384.0    1.0
# transition_type[within cluster]                      2517.0    1.0
# walk_length:transition_type[1400, within cluster]    2807.0    1.0
# walk_length:transition_type[6, within cluster]       2689.0    1.0
# walk_length:transition_type[3, within cluster]       2467.0    1.0
# rt_sigma                                             3053.0    1.0

# %%
az.to_netcdf(sample, 'bayesian_model0')
# Out:
# 'bayesian_model0'
