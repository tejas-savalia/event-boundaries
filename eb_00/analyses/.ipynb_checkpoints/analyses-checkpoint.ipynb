# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stat

# %%
p_data = []
for participant in range(4, 96):
    try:
        p_dataframe = pd.read_csv('data/'+str(participant)+'.csv')
        p_dataframe['p_no'] = participant
        p_data.append(p_dataframe)
        
    except:
        print(participant)
# Out:
# 11
# 27
# 28
# 33
# 46
# 47
# 48
# 49
# 54

# %%
data = pd.concat(p_data)

# %%
len(p_data)
# Out:
# 83

# %%
data_choice = data[data['key_resp.rt'].notna()]

# %%
data_choice['block no.'] = np.tile(np.repeat(np.arange(1, 31), 30), len(p_data))
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\3202552857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice['block no.'] = np.tile(np.repeat(np.arange(1, 31), 30), len(p_data))

# %%
data_choice['switch type'] = 'reward'
data_choice.loc[data_choice['p_no']%2 != 0, 'switch type'] = 'transition'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\799418867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice['switch type'] = 'reward'

# %%
data_choice['infect key change'] = 'yes'
data_choice.loc[((data_choice['switch type'] == 'reward') & (data_choice['p_no'] > 50)), 'infect key change'] = 'no'
data_choice.loc[((data_choice['switch type'] == 'transition') & (data_choice['p_no'] < 50)), 'infect key change'] = 'no'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\986198175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice['infect key change'] = 'yes'

# %%
data_choice.loc[:, 'boundary node?'] = 'no'
data_choice.loc[((data_choice['index'] == 1.0) |
                 (data_choice['index'] == 5.0) |
                 (data_choice['index'] == 6.0) |
                 (data_choice['index'] == 10.0) |
                 (data_choice['index'] == 11.0) |
                 (data_choice['index'] == 15.0)
                ),
                'boundary node?'] = 'yes'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\2784336044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice.loc[:, 'boundary node?'] = 'no'

# %%
## Labeling post transition boundaries
post_transition_boundary = np.zeros(len(data_choice), dtype = object)
prev_node = None
node_counter = 0
post_transition_boundary[0] = 'no'
for curr_node, next_node in zip(data_choice['boundary node?'].values[:-1], data_choice['boundary node?'].values[1:]):
    node_counter = node_counter+1
    if curr_node == 'yes' and next_node == 'yes':
        post_transition_boundary[node_counter] = 'yes'
    else:
        post_transition_boundary[node_counter] = 'no'
data_choice['post transition node'] = post_transition_boundary  
data_choice.loc[((data_choice['post transition node'] == 'yes') & (data_choice['boundary node?'] == 'yes')), 'node type'] = 'community receiver'
data_choice.loc[((data_choice['post transition node'] == 'no') & (data_choice['boundary node?'] == 'yes')), 'node type'] = 'community sender'
data_choice.loc[((data_choice['post transition node'] == 'no') & (data_choice['boundary node?'] == 'no')), 'node type'] = 'community node'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\318945277.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice['post transition node'] = post_transition_boundary
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\318945277.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice.loc[((data_choice['post transition node'] == 'yes') & (data_choice['boundary node?'] == 'yes')), 'node type'] = 'community receiver'

# %%
data_choice.loc[((data_choice['index'] == 3) | (data_choice['index'] == 8) & (data_choice['switch type'] == 'transition')), 'node type'] = 'Transition infected node'
data_choice.loc[((data_choice['index'] == 2) | (data_choice['index'] == 13) & (data_choice['switch type'] == 'reward')), 'node type'] = 'Reward infected node'
data_choice.loc[(data_choice['block no.'] <= 20), 'stage'] = 'pre infection'
data_choice.loc[(data_choice['block no.'] > 20), 'stage'] = 'post infection'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\1307958866.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice.loc[(data_choice['block no.'] <= 20), 'stage'] = 'pre infection'

# %%
#Remove RT outliers
data_choice = data_choice[data_choice['key_resp.rt'] < 10]

# %%
g = sns.catplot(x = 'node type', y = 'key_resp.rt', col = 'switch type', hue = 'stage', 
           data = data_choice,
           kind = 'bar', margin_titles = True)#, row_order = ['yes', 'no'])
g.set_xticklabels(rotation = 90)

# %%
g = sns.catplot(y = 'key_resp.rt', x = 'switch type', col = 'stage', hue = 'node type', 
           data = data_choice.loc[((data_choice['block no.'] >= 20) & (data_choice['node type'] == 'Transition infected node') | (data_choice['node type'] == 'Reward infected node') | (data_choice['node type'] == 'community node'))],  
           kind = 'bar')
# g.set('block 1')

# %%
data_choice['meta_node_type'] = 'other_nodes'
data_choice.loc[(((data_choice['node type'] == 'Transition infected node') | (data_choice['node type'] == 'community node')) & (data_choice['switch type'] == 'reward')), 'meta_node_type'] = 'uninfected'
data_choice.loc[(((data_choice['node type'] == 'Reward infected node') | (data_choice['node type'] == 'community node')) & (data_choice['switch type'] == 'transition')), 'meta_node_type'] = 'uninfected'
data_choice.loc[((data_choice['node type'] == 'Transition infected node') & (data_choice['switch type'] == 'transition')), 'meta_node_type'] = 'infected'
data_choice.loc[((data_choice['node type'] == 'Reward infected node') & (data_choice['switch type'] == 'reward')), 'meta_node_type'] = 'infected'
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18916\1706767411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_choice['meta_node_type'] = 'other_nodes'

# %%
g = sns.catplot(y = 'key_resp.rt', col = 'infect key change', x = 'switch type', row = 'stage', hue = 'meta_node_type', 
           data = data_choice.loc[((data_choice['block no.'] >= 20))], hue_order = ['uninfected', 'infected'],  
           kind = 'bar')
# g.set('block 1')

# %%
stat.ttest_ind(data_choice.loc[((data_choice['block no.'] >= 20) & (data_choice['switch type'] == 'transition') & (data_choice['meta_node_type'] == 'infected')), 'rt'], data_choice.loc[((data_choice['block no.'] >= 20) & (data_choice['switch type'] == 'transition') & (data_choice['meta_node_type'] == 'uninfected')), 'rt'])
# Out:
# Ttest_indResult(statistic=2.8321713949434884, pvalue=0.004649299843249827)

# %%
data_choice['switch_type'] = data_choice['switch type']
data_choice['node_type'] = data_choice['node type']
data_choice['rt'] = data_choice['key_resp.rt']

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

lm = ols('rt ~ C(switch_type)*C(stage)', 
         data = data_choice.loc[((data_choice['meta_node_type'] == 'infected'))].reset_index()).fit()
table = sm.stats.anova_lm(lm, type=2)

# %%
table
# Out:
#                              df       sum_sq    mean_sq          F  \
# C(switch_type)              1.0     0.600867   0.600867   0.659591
# C(stage)                    1.0    33.210706  33.210706  36.456470
# C(switch_type):C(stage)     1.0    10.338840  10.338840  11.349280
# Residual                 4547.0  4142.175072   0.910969        NaN
#
#                                PR(>F)
# C(switch_type)           4.167468e-01
# C(stage)                 1.685480e-09
# C(switch_type):C(stage)  7.610516e-04
# Residual                          NaN

# %%
sns.set_context('talk')
g = sns.catplot(x = 'block no.', y = 'key_resp.rt', col = 'switch type', hue = 'node type', 
           data = data_choice.loc[((data_choice['block no.'] >= 20))],  
           margin_titles = True, kind = 'point', hue_order=['community node', 'Reward infected node', 'Transition infected node'])#, col_wrap = 3)
g.set_xticklabels(rotation = 90)
for i in range(5):
    g.axes[i].axvline(x = 20, ls = '--', color = 'black')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-6c0109e5b86b> in <module>
#       5 g.set_xticklabels(rotation = 90)
#       6 for i in range(5):
# ----> 7     g.axes[i].axvline(x = 20, ls = '--', color = 'black')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'axvline'

# %%
data_parse = data[data['parse_stim.started'].notna()]

# %%
data_parse.loc[:, 'boundary node?'] = 'no'
data_parse.loc[((data_parse['index'] == 1.0) |
                 (data_parse['index'] == 5.0) |
                 (data_parse['index'] == 6.0) |
                 (data_parse['index'] == 10.0) |
                 (data_parse['index'] == 11.0) |
                 (data_parse['index'] == 15.0)
                ),
                'boundary node?'] = 'yes'
# Out:
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
data_parse['block no.'] = np.tile(np.repeat(np.arange(1, 21), 30), len(p_data))
# Out:
# <ipython-input-7-cfb58037f483>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_parse['block no.'] = np.tile(np.repeat(np.arange(1, 21), 30), len(p_data))

# %%
data_parse['key pressed'] = 0
data_parse.loc[data_parse['parse_key_resp.keys']=='space', 'key pressed'] = 1
# Out:
# <ipython-input-8-351727d7295d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_parse['key pressed'] = 0

# %%
## Labeling post transition boundaries
post_transition_boundary = np.zeros(len(data_parse), dtype = object)
prev_node = None
node_counter = 0
post_transition_boundary[0] = 'no'
for curr_node, next_node in zip(data_parse['boundary node?'].values[:-1], data_parse['boundary node?'].values[1:]):
    node_counter = node_counter+1
    if curr_node == 'yes' and next_node == 'yes':
        post_transition_boundary[node_counter] = 'yes'
    else:
        post_transition_boundary[node_counter] = 'no'
data_parse['post transition node'] = post_transition_boundary  
data_parse.loc[((data_parse['post transition node'] == 'yes') & (data_parse['boundary node?'] == 'yes')), 'node type'] = 'community receiver'
data_parse.loc[((data_parse['post transition node'] == 'no') & (data_parse['boundary node?'] == 'yes')), 'node type'] = 'community sender'
data_parse.loc[((data_parse['post transition node'] == 'no') & (data_parse['boundary node?'] == 'no')), 'node type'] = 'community node'
# Out:
# <ipython-input-9-07ed7ba307d8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_parse['post transition node'] = post_transition_boundary
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
data_parse['switch type'] = 'reward'
data_parse.loc[data_parse['p_no']%2 != 0, 'switch type'] = 'transition'

data_parse.loc[((data_parse['index'] == 3) | (data_parse['index'] == 8) & (data_parse['switch type'] == 'transition')), 'node type'] = 'Transition infected node'
data_parse.loc[((data_parse['index'] == 2) | (data_parse['index'] == 13) & (data_parse['switch type'] == 'reward')), 'node type'] = 'Reward infected node'
data_parse.loc[(data_parse['block no.'] <= 10), 'stage'] = 'pre infection'
data_parse.loc[(data_parse['block no.'] > 10), 'stage'] = 'post infection'
# Out:
# <ipython-input-10-a153271526e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_parse['switch type'] = 'reward'
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Tejas\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
data_parse_proportion = data_parse.groupby(by = ['p_no', 'boundary node?', 'node type', 'block no.', 'switch type', 'stage']).mean().reset_index()

# %%
sns.set_context('talk')
g = sns.catplot(x = 'node type', y = 'key pressed',  col = 'switch type', hue = 'stage',
           data = data_parse_proportion, order = ['community node', 'community receiver'],
           kind = 'bar', margin_titles = True)
g.set(ylabel='Key press probability')
g.set_xticklabels(['community \n node', 'community \n receiver'])

# %%
data_parse_proportion['key_pressed'] = data_parse_proportion['key pressed']
data_parse_proportion['node_type'] = data_parse_proportion['node type']
data_parse_proportion['switch_type'] = data_parse_proportion['switch type']

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

lm = ols('key_pressed ~ C(switch_type)*C(node_type)*C(stage)', 
         data = data_parse_proportion.loc[((data_parse_proportion['node type']=='community node') | (data_parse_proportion['node type'] == 'community receiver'))].reset_index()).fit()
table = sm.stats.anova_lm(lm, type=2)

# %%
table
# Out:
#                                           df     sum_sq   mean_sq         F  \
# C(switch_type)                           1.0   0.047539  0.047539  0.888207
# C(node_type)                             1.0   0.001979  0.001979  0.036982
# C(stage)                                 1.0   0.009328  0.009328  0.174287
# C(switch_type):C(node_type)              1.0   0.153995  0.153995  2.877224
# C(switch_type):C(stage)                  1.0   0.001507  0.001507  0.028153
# C(node_type):C(stage)                    1.0   0.192348  0.192348  3.593823
# C(switch_type):C(node_type):C(stage)     1.0   0.152684  0.152684  2.852733
# Residual                              1512.0  80.925113  0.053522       NaN
#
#                                         PR(>F)
# C(switch_type)                        0.346114
# C(node_type)                          0.847528
# C(stage)                              0.676389
# C(switch_type):C(node_type)           0.090047
# C(switch_type):C(stage)               0.866773
# C(node_type):C(stage)                 0.058185
# C(switch_type):C(node_type):C(stage)  0.091425
# Residual                                   NaN

# %%
data_parse_proportion.loc[((data_parse_proportion['node type']=='community node') | (data_parse_proportion['node type'] == 'community receiver'))]
# Out:
#       p_no boundary node?           node type  block no. switch type  \
# 40       4             no      community node          1      reward
# 41       4             no      community node          2      reward
# 42       4             no      community node          3      reward
# 43       4             no      community node          4      reward
# 44       4             no      community node          5      reward
# ...    ...            ...                 ...        ...         ...
# 3775    45            yes  community receiver         16  transition
# 3776    45            yes  community receiver         17  transition
# 3777    45            yes  community receiver         18  transition
# 3778    45            yes  community receiver         19  transition
# 3779    45            yes  community receiver         20  transition
#
#                stage     index  stimulus_selector.thisRepN  \
# 40     pre infection  9.000000                         NaN
# 41     pre infection  9.000000                         NaN
# 42     pre infection  9.000000                         NaN
# 43     pre infection  9.000000                         NaN
# 44     pre infection  9.000000                         NaN
# ...              ...       ...                         ...
# 3775  post infection  7.333333                         NaN
# 3776  post infection  8.666667                         NaN
# 3777  post infection  8.666667                         NaN
# 3778  post infection  7.333333                         NaN
# 3779  post infection  7.333333                         NaN
#
#       stimulus_selector.thisTrialN  stimulus_selector.thisN  ...  participant  \
# 40                             NaN                      NaN  ...          4.0
# 41                             NaN                      NaN  ...          4.0
# 42                             NaN                      NaN  ...          4.0
# 43                             NaN                      NaN  ...          4.0
# 44                             NaN                      NaN  ...          4.0
# ...                            ...                      ...  ...          ...
# 3775                           NaN                      NaN  ...         45.0
# 3776                           NaN                      NaN  ...         45.0
# 3777                           NaN                      NaN  ...         45.0
# 3778                           NaN                      NaN  ...         45.0
# 3779                           NaN                      NaN  ...         45.0
#
#       session   frameRate  Unnamed: 95  parse_stim.stopped  \
# 40        1.0  119.962305          NaN                 NaN
# 41        1.0  119.962305          NaN                 NaN
# 42        1.0  119.962305          NaN                 NaN
# 43        1.0  119.962305          NaN                 NaN
# 44        1.0  119.962305          NaN                 NaN
# ...       ...         ...          ...                 ...
# 3775      1.0  100.215618          NaN                 NaN
# 3776      1.0  100.215618          NaN                 NaN
# 3777      1.0  100.215618          NaN                 NaN
# 3778      1.0  100.215618          NaN                 NaN
# 3779      1.0  100.215618          NaN                 NaN
#
#       parse_key_resp.stopped  parse_trial_instr.stopped  \
# 40                       NaN                        NaN
# 41                       NaN                        NaN
# 42                       NaN                        NaN
# 43                       NaN                        NaN
# 44                       NaN                        NaN
# ...                      ...                        ...
# 3775                     NaN                        NaN
# 3776                     NaN                        NaN
# 3777                     NaN                        NaN
# 3778                     NaN                        NaN
# 3779                     NaN                        NaN
#
#       parse_feedback_txt.stopped  Unnamed: 99  key pressed
# 40                           NaN          NaN     0.000000
# 41                           NaN          NaN     0.083333
# 42                           NaN          NaN     0.083333
# 43                           NaN          NaN     0.083333
# 44                           NaN          NaN     0.000000
# ...                          ...          ...          ...
# 3775                         NaN          NaN     0.333333
# 3776                         NaN          NaN     0.333333
# 3777                         NaN          NaN     0.333333
# 3778                         NaN          NaN     0.666667
# 3779                         NaN          NaN     0.666667
#
# [1520 rows x 93 columns]

# %%
data_choice.loc[((data_choice['node type'] == 'Reward infected node') & (data_choice['stage'] == 'post infection'))]
# Out:
#       index        stimulus correct_answer  stimulus_selector.thisRepN  \
# 940     2.0   stimuli/2.png              s                         NaN
# 943     2.0   stimuli/2.png              s                         NaN
# 960    13.0  stimuli/13.png              l                         NaN
# 965    13.0  stimuli/13.png              l                         NaN
# 969     2.0   stimuli/2.png              s                         NaN
# ...     ...             ...            ...                         ...
# 1183    2.0   stimuli/2.png              s                         NaN
# 1188    2.0   stimuli/2.png              s                         NaN
# 1191    2.0   stimuli/2.png              s                         NaN
# 1242    2.0   stimuli/2.png              s                         NaN
# 1245    2.0   stimuli/2.png              s                         NaN
#
#       stimulus_selector.thisTrialN  stimulus_selector.thisN  \
# 940                            NaN                      NaN
# 943                            NaN                      NaN
# 960                            NaN                      NaN
# 965                            NaN                      NaN
# 969                            NaN                      NaN
# ...                            ...                      ...
# 1183                           NaN                      NaN
# 1188                           NaN                      NaN
# 1191                           NaN                      NaN
# 1242                           NaN                      NaN
# 1245                           NaN                      NaN
#
#       stimulus_selector.thisIndex  trials.thisRepN  trials.thisTrialN  \
# 940                           NaN              NaN                NaN
# 943                           NaN              NaN                NaN
# 960                           NaN              NaN                NaN
# 965                           NaN              NaN                NaN
# 969                           NaN              NaN                NaN
# ...                           ...              ...                ...
# 1183                          NaN              NaN                NaN
# 1188                          NaN              NaN                NaN
# 1191                          NaN              NaN                NaN
# 1242                          NaN              NaN                NaN
# 1245                          NaN              NaN                NaN
#
#       trials.thisN  ...  parse_key_resp.stopped  parse_trial_instr.stopped  \
# 940            NaN  ...                     NaN                        NaN
# 943            NaN  ...                     NaN                        NaN
# 960            NaN  ...                     NaN                        NaN
# 965            NaN  ...                     NaN                        NaN
# 969            NaN  ...                     NaN                        NaN
# ...            ...  ...                     ...                        ...
# 1183           NaN  ...                     NaN                        NaN
# 1188           NaN  ...                     NaN                        NaN
# 1191           NaN  ...                     NaN                        NaN
# 1242           NaN  ...                     NaN                        NaN
# 1245           NaN  ...                     NaN                        NaN
#
#       parse_feedback_txt.stopped  Unnamed: 99  block no.  switch type  \
# 940                          NaN          NaN         21       reward
# 943                          NaN          NaN         21       reward
# 960                          NaN          NaN         21       reward
# 965                          NaN          NaN         21       reward
# 969                          NaN          NaN         22       reward
# ...                          ...          ...        ...          ...
# 1183                         NaN          NaN         28   transition
# 1188                         NaN          NaN         29   transition
# 1191                         NaN          NaN         29   transition
# 1242                         NaN          NaN         30   transition
# 1245                         NaN          NaN         30   transition
#
#       boundary node?  post transition node             node type  \
# 940               no                    no  Reward infected node
# 943               no                    no  Reward infected node
# 960               no                    no  Reward infected node
# 965               no                    no  Reward infected node
# 969               no                    no  Reward infected node
# ...              ...                   ...                   ...
# 1183              no                    no  Reward infected node
# 1188              no                    no  Reward infected node
# 1191              no                    no  Reward infected node
# 1242              no                    no  Reward infected node
# 1245              no                    no  Reward infected node
#
#                stage
# 940   post infection
# 943   post infection
# 960   post infection
# 965   post infection
# 969   post infection
# ...              ...
# 1183  post infection
# 1188  post infection
# 1191  post infection
# 1242  post infection
# 1245  post infection
#
# [1157 rows x 108 columns]
