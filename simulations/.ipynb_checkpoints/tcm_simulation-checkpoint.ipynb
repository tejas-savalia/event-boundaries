# %%
from utils import *
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from multiprocessing import pool

# %%
modular_graph = create_adjacency_matrix_for_modular_graph(15, 3, [5, 5, 5], [(0, 14), (4, 5), (9, 10)], [0, 4, 5, 9, 10, 14])
# walk = random_hop(modular_graph, 1000, 1000).astype(int)

# %%
def simulate_tcm_encoder(alpha, beta, walk_length, num_trials):
    walk = random_hop(modular_graph, walk_length, num_trials).astype(int)
    items = np.identity(15)
    context = np.random.uniform(0, 1, (15, 15))
    presented_items = items[walk]
    m_fc = np.random.uniform(0, 1, (15, 15))
    m_fc_ten = np.random.uniform(0, 1, (walk_length, 15, 15))
    
    for i in range(1, walk_length):
        m_fc_ten[i-1] = m_fc

        c_IN = np.dot(m_fc, presented_items[i])
        c_IN = c_IN/np.linalg.norm(c_IN)
        rho = np.sqrt(1+(beta**2)*((np.dot(context[walk[i-1]] , c_IN)**2)-1)) - beta*np.dot(context[walk[i-1]],c_IN);
        
        context[walk[i]] = rho*context[walk[i-1]] + beta*c_IN
        
        m_fc[walk[i]] = m_fc[walk[i]] + alpha*np.dot(presented_items[walk[i]], context[walk[i-1]])

    return m_fc, walk, context, m_fc_ten

# %%
walk_length = 500
m_fc, walk, context, m_fc_ten = simulate_tcm_encoder(alpha=0.4, beta=0.9, walk_length=walk_length, num_trials=500)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_25000\2966406238.py:13: RuntimeWarning: invalid value encountered in divide
#   c_IN = c_IN/np.linalg.norm(c_IN)

# %%
# sns.heatmap(m_fc)
# plt.title('walk length: ' + str(walk_length-1))

# %%
sns.heatmap(m_fc)
# Out:
# c:\Users\tejas\Anaconda3\envs\eb\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# c:\Users\tejas\Anaconda3\envs\eb\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <AxesSubplot: >

# %%
walk[-10:]
# Out:
# array([12, 11, 13, 14, 11, 12, 13, 12, 10, 11])

# %%
1/15
# Out:
# 0.06666666666666667

# %%
def compute_entropy(context_matrix):
    node_entropy = np.zeros(context_matrix.shape[0])
    for node in range(context_matrix.shape[0]):
        node_entropy[node] = -np.sum(context_matrix[node]*np.log(context_matrix[node]))
    return node_entropy

# %%
def compute_entropy_diff(node_entropies, boundary_nodes):
    boundary_entropy = np.mean(node_entropies[boundary_nodes])
    nonboundary_entropy = np.mean(np.delete(node_entropies, boundary_nodes))
    return boundary_entropy-nonboundary_entropy

# %%
alpha = [0.01, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99]
beta = [0.01, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99]
walk_length = [1, 2, 3, 4, 5, 1000]
num_trials = [1000]
iterations = np.arange(100)
params = itertools.product(iterations, alpha, beta, walk_length, num_trials)

# %%
def sim_tcm_boundary_entropy(params):
    context_matrix = simulate_tcm_encoder(alpha=params[1], beta=params[2], walk_length=params[3], num_trials=params[4])
    node_entropy = compute_entropy(context_matrix)
    boundary_diff = compute_entropy_diff(node_entropy, np.array([0, 4, 5, 9, 10, 14]))
    return boundary_diff

# %%
boundary_diff = np.array([sim_tcm_boundary_entropy(param) for param in params])

# %%
# params = itertools.product(iterations, alpha, beta, walk_length, num_trials)
# list(params)

# %%
boundary_diff_df = pd.DataFrame({'iteration': np.repeat(iterations, len(beta)*len(alpha)*len(walk_length)),
                                'alpha': np.tile(np.repeat(alpha, len(beta)*len(walk_length)), len(iterations)),
                                 'beta': np.tile(np.repeat(beta, len(walk_length)), len(alpha)*len(iterations)),
                                 'walk_length': np.tile(walk_length, len(alpha)*len(beta)*len(iterations)),
                                 'boundary_diff': boundary_diff
                                 })

# %%
sns.catplot(x = 'alpha', y = 'boundary_diff', hue = 'beta', data = boundary_diff_df.loc[boundary_diff_df['walk_length']!=1000], col = 'walk_length', 
            col_wrap = 3, kind = 'point')

# %%
sns.catplot(x = 'alpha', y = 'boundary_diff', hue = 'beta', data = boundary_diff_df.loc[boundary_diff_df['walk_length']==1000], col = 'walk_length', 
            kind = 'point')
